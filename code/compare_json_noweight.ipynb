# %% [markdown]
# # Accuracy Report
# This notebook provides a visual analysis of the extraction accuracy compared to the ground truth across multiple documents.

# %% [markdown]
# ### Visualisation script

# %%
import json
import difflib
import os
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# Global list to store summary results
batch_summary = []

def calculate_accuracy(str1, str2):
    str1 = str(str1).strip()
    str2 = str(str2).strip()
    if not str1 and not str2:
        return 100.0
    matcher = difflib.SequenceMatcher(None, str1, str2)
    return round(matcher.ratio() * 100, 2)

def get_comparison_data(gt_path, res_path):
    with open(gt_path, 'r', encoding='utf-8') as f:
        gt = json.load(f)
    with open(res_path, 'r', encoding='utf-8') as f:
        res = json.load(f)

    data = []
    
    # Top-level fields
    for key in gt.keys():
        if key == 'line_items': continue
        val_gt = gt.get(key)
        val_res = res.get(key, "")
        
        if not val_gt or str(val_gt).strip() == "":
            continue
            
        acc = calculate_accuracy(val_gt, val_res)
        data.append({"Field": key, "Accuracy": acc, "Ground Truth": val_gt, "Result": val_res, "Category": "Header"})

    # Line items
    gt_items = gt.get('line_items', [])
    res_items = res.get('line_items', [])
    for i, item_gt in enumerate(gt_items):
        item_res = res_items[i] if i < len(res_items) else {}
        for k, v_gt in item_gt.items():
            if not v_gt or str(v_gt).strip() == "": continue
            v_res = item_res.get(k, "")
            acc = calculate_accuracy(v_gt, v_res)
            data.append({"Field": f"Item_{i+1}_{k}", "Accuracy": acc, "Ground Truth": v_gt, "Result": v_res, "Category": "Line Item"})
            
    return pd.DataFrame(data)

def generate_visual_report(df, filename):
    if df.empty:
        print(f"No data to report for {filename}.")
        return

    overall_acc = df['Accuracy'].mean()
    
    # Store in summary
    batch_summary.append({"File": filename, "Score": overall_acc, "Fields": len(df)})

    display(HTML(f"<h1 style='border-bottom: 2px solid #334155; padding-bottom: 10px; margin-top: 50px;'>Report: {filename}</h1>"))

    # 1. Summary Card
    summary_html = f"""
    <div style="padding: 20px; border-radius: 10px; background-color: #f8fafc; border-left: 8px solid #4CAF50; margin-bottom: 24px; box-shadow: 0 4px 6px -1px rgb(0 0 0 / 0.1);">
        <h2 style="margin: 0; color: #1e293b; font-family: sans-serif;">Extraction Accuracy Summary</h2>
        <div style="display: flex; align-items: center; margin-top: 12px;">
            <span style="font-size: 16px; color: #64748b; margin-right: 8px;">Overall Score:</span>
            <span style="color: #16a34a; font-size: 28px; font-weight: bold;">{overall_acc:.2f}%</span>
        </div>
        <p style="margin: 8px 0 0 0; color: #64748b; font-size: 14px;">Total Fields Evaluated: <b style="color: #334155;">{len(df)}</b></p>
    </div>
    """
    display(HTML(summary_html))

    # 2. Bar Chart
    plt.figure(figsize=(10, len(df) * 0.45))
    colors = ['#22c55e' if x > 95 else '#84cc16' if x > 90 else '#eab308' if x > 70 else '#ef4444' for x in df['Accuracy']]
    plt.barh(df['Field'], df['Accuracy'], color=colors, height=0.7)
    plt.xlabel('Accuracy %')
    plt.title(f'Field Accuracy - {filename}')
    plt.xlim(0, 110)
    plt.grid(axis='x', linestyle='--', alpha=0.3)
    plt.gca().invert_yaxis()
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    for i, v in enumerate(df['Accuracy']):
        plt.text(v + 1, i, f"{v}%", color='#334155', va='center')
    plt.tight_layout()
    plt.show()

    # 3. Styled Table
    def style_accuracy_col(val):
        if val > 95: bg, text = '#f0fdf4', '#166534'
        elif val > 90: bg, text = '#ecfdf5', '#065f46'
        elif val > 70: bg, text = '#fffbeb', '#92400e'
        else: bg, text = '#fef2f2', '#991b1b'
        return f'background-color: {bg}; color: {text}; font-weight: bold;'

    styled_df = df.style.map(style_accuracy_col, subset=['Accuracy'])\
                       .format({"Accuracy": "{:.2f}%"})\
                       .set_properties(**{'text-align': 'left', 'padding': '12px 15px', 'border-bottom': '1px solid #e2e8f0', 'font-family': 'sans-serif'})\
                       .set_table_styles([
                           {'selector': 'th', 'props': [('background-color', '#f8fafc'), ('color', '#475569'), ('font-weight', 'bold'), ('text-transform', 'uppercase'), ('font-size', '12px')]},
                           {'selector': 'tr:hover', 'props': [('background-color', '#f1f5f9')]}
                       ])
    
    display(styled_df)

# Execution Loop
result_dir = '/Users/pat/Desktop/custom_FM/working/comparison/result/'
gt_dir = '/Users/pat/Desktop/custom_FM/working/comparison/ground_truth/converted/'

batch_summary = [] # Reset summary

for res_file in sorted(os.listdir(result_dir)):
    if res_file.startswith("output_") and res_file.endswith(".json"):
        # Identify the ID (e.g., MSV-001)
        file_id = res_file.replace("output_", "").replace(".json", "")
        gt_file = f"{file_id}.json"
        
        res_path = os.path.join(result_dir, res_file)
        gt_path = os.path.join(gt_dir, gt_file)
        
        if os.path.exists(gt_path):
            df_results = get_comparison_data(gt_path, res_path)
            generate_visual_report(df_results, file_id)
        else:
            print(f"Warning: No Ground Truth found for {file_id}")
# Out:
# <h1 style='border-bottom: 2px solid #334155; padding-bottom: 10px; margin-top: 50px;'>Report: INT-001</h1>
#     <div style="padding: 20px; border-radius: 10px; background-color: #f8fafc; border-left: 8px solid #4CAF50; margin-bottom: 24px; box-shadow: 0 4px 6px -1px rgb(0 0 0 / 0.1);">
#         <h2 style="margin: 0; color: #1e293b; font-family: sans-serif;">Extraction Accuracy Summary</h2>
#         <div style="display: flex; align-items: center; margin-top: 12px;">
#             <span style="font-size: 16px; color: #64748b; margin-right: 8px;">Overall Score:</span>
#             <span style="color: #16a34a; font-size: 28px; font-weight: bold;">88.74%</span>
#         </div>
#         <p style="margin: 8px 0 0 0; color: #64748b; font-size: 14px;">Total Fields Evaluated: <b style="color: #334155;">14</b></p>
#     </div>
# <style type="text/css">
# #T_1d8c4 th {
#   background-color: #f8fafc;
#   color: #475569;
#   font-weight: bold;
#   text-transform: uppercase;
#   font-size: 12px;
# }
# #T_1d8c4 tr:hover {
#   background-color: #f1f5f9;
# }
# #T_1d8c4_row0_col0, #T_1d8c4_row0_col2, #T_1d8c4_row0_col3, #T_1d8c4_row0_col4, #T_1d8c4_row1_col0, #T_1d8c4_row1_col2, #T_1d8c4_row1_col3, #T_1d8c4_row1_col4, #T_1d8c4_row2_col0, #T_1d8c4_row2_col2, #T_1d8c4_row2_col3, #T_1d8c4_row2_col4, #T_1d8c4_row3_col0, #T_1d8c4_row3_col2, #T_1d8c4_row3_col3, #T_1d8c4_row3_col4, #T_1d8c4_row4_col0, #T_1d8c4_row4_col2, #T_1d8c4_row4_col3, #T_1d8c4_row4_col4, #T_1d8c4_row5_col0, #T_1d8c4_row5_col2, #T_1d8c4_row5_col3, #T_1d8c4_row5_col4, #T_1d8c4_row6_col0, #T_1d8c4_row6_col2, #T_1d8c4_row6_col3, #T_1d8c4_row6_col4, #T_1d8c4_row7_col0, #T_1d8c4_row7_col2, #T_1d8c4_row7_col3, #T_1d8c4_row7_col4, #T_1d8c4_row8_col0, #T_1d8c4_row8_col2, #T_1d8c4_row8_col3, #T_1d8c4_row8_col4, #T_1d8c4_row9_col0, #T_1d8c4_row9_col2, #T_1d8c4_row9_col3, #T_1d8c4_row9_col4, #T_1d8c4_row10_col0, #T_1d8c4_row10_col2, #T_1d8c4_row10_col3, #T_1d8c4_row10_col4, #T_1d8c4_row11_col0, #T_1d8c4_row11_col2, #T_1d8c4_row11_col3, #T_1d8c4_row11_col4, #T_1d8c4_row12_col0, #T_1d8c4_row12_col2, #T_1d8c4_row12_col3, #T_1d8c4_row12_col4, #T_1d8c4_row13_col0, #T_1d8c4_row13_col2, #T_1d8c4_row13_col3, #T_1d8c4_row13_col4 {
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_1d8c4_row0_col1, #T_1d8c4_row1_col1, #T_1d8c4_row3_col1, #T_1d8c4_row6_col1, #T_1d8c4_row7_col1, #T_1d8c4_row8_col1, #T_1d8c4_row9_col1, #T_1d8c4_row10_col1, #T_1d8c4_row12_col1, #T_1d8c4_row13_col1 {
#   background-color: #f0fdf4;
#   color: #166534;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_1d8c4_row2_col1 {
#   background-color: #fffbeb;
#   color: #92400e;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_1d8c4_row4_col1, #T_1d8c4_row11_col1 {
#   background-color: #fef2f2;
#   color: #991b1b;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_1d8c4_row5_col1 {
#   background-color: #ecfdf5;
#   color: #065f46;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# </style>
# <table id="T_1d8c4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d8c4_level0_col0" class="col_heading level0 col0" >Field</th>
#       <th id="T_1d8c4_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1d8c4_level0_col2" class="col_heading level0 col2" >Ground Truth</th>
#       <th id="T_1d8c4_level0_col3" class="col_heading level0 col3" >Result</th>
#       <th id="T_1d8c4_level0_col4" class="col_heading level0 col4" >Category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d8c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1d8c4_row0_col0" class="data row0 col0" >invoice_number</td>
#       <td id="T_1d8c4_row0_col1" class="data row0 col1" >100.00%</td>
#       <td id="T_1d8c4_row0_col2" class="data row0 col2" >25102400095</td>
#       <td id="T_1d8c4_row0_col3" class="data row0 col3" >25102400095</td>
#       <td id="T_1d8c4_row0_col4" class="data row0 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1d8c4_row1_col0" class="data row1 col0" >invoice_date</td>
#       <td id="T_1d8c4_row1_col1" class="data row1 col1" >100.00%</td>
#       <td id="T_1d8c4_row1_col2" class="data row1 col2" >24/10/2025</td>
#       <td id="T_1d8c4_row1_col3" class="data row1 col3" >24/10/2025</td>
#       <td id="T_1d8c4_row1_col4" class="data row1 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1d8c4_row2_col0" class="data row2 col0" >supplier_name_th</td>
#       <td id="T_1d8c4_row2_col1" class="data row2 col1" >89.47%</td>
#       <td id="T_1d8c4_row2_col2" class="data row2 col2" >บริษัท อินเทอร์เน็ตประเทศไทย จำกัด (มหาชน)</td>
#       <td id="T_1d8c4_row2_col3" class="data row2 col3" >บริษัท อินเทอร์เน็ตประเทศไทย จำกัด</td>
#       <td id="T_1d8c4_row2_col4" class="data row2 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1d8c4_row3_col0" class="data row3 col0" >supplier_tax_id</td>
#       <td id="T_1d8c4_row3_col1" class="data row3 col1" >96.00%</td>
#       <td id="T_1d8c4_row3_col2" class="data row3 col2" >0107544000094</td>
#       <td id="T_1d8c4_row3_col3" class="data row3 col3" >010754400094</td>
#       <td id="T_1d8c4_row3_col4" class="data row3 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1d8c4_row4_col0" class="data row4 col0" >customer_name_th</td>
#       <td id="T_1d8c4_row4_col1" class="data row4 col1" >30.30%</td>
#       <td id="T_1d8c4_row4_col2" class="data row4 col2" >บจก. อินโนเวทีฟ เอ็กซ์ตรีมิสต์</td>
#       <td id="T_1d8c4_row4_col3" class="data row4 col3" >บกธ.อินเทอร์พีเคชั่นส์ คอร์เปอเรชั่น</td>
#       <td id="T_1d8c4_row4_col4" class="data row4 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1d8c4_row5_col0" class="data row5 col0" >customer_address_th</td>
#       <td id="T_1d8c4_row5_col1" class="data row5 col1" >90.57%</td>
#       <td id="T_1d8c4_row5_col2" class="data row5 col2" >เลขที่ 3 อาคาร พร้อมพันธุ์ 3 ห้องเลขที่ 1608-1614 ชั้นที่ 16 ซอย ลาดพร้าว 3 ถนน
# ลาดพร้าว
# แขวง จอมพล เขต จตุจักร กรุงเทพมหานคร 10900</td>
#       <td id="T_1d8c4_row5_col3" class="data row5 col3" >เลขที่ 3 อาคาร พร้อมเพื่อนๆ 3 ห้องเลขที่ 1608-1614 ชั้นที่ 16 ซอย ลาดพร้าว 3 ถนน สาทรปราการ แขวง จอมพล เขต จตุจักร กรุงเทพมหานคร 10900</td>
#       <td id="T_1d8c4_row5_col4" class="data row5 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1d8c4_row6_col0" class="data row6 col0" >customer_tax_id</td>
#       <td id="T_1d8c4_row6_col1" class="data row6 col1" >96.00%</td>
#       <td id="T_1d8c4_row6_col2" class="data row6 col2" >0105551117714</td>
#       <td id="T_1d8c4_row6_col3" class="data row6 col3" >010551117714</td>
#       <td id="T_1d8c4_row6_col4" class="data row6 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1d8c4_row7_col0" class="data row7 col0" >net_amount</td>
#       <td id="T_1d8c4_row7_col1" class="data row7 col1" >100.00%</td>
#       <td id="T_1d8c4_row7_col2" class="data row7 col2" >600.00</td>
#       <td id="T_1d8c4_row7_col3" class="data row7 col3" >600.00</td>
#       <td id="T_1d8c4_row7_col4" class="data row7 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1d8c4_row8_col0" class="data row8 col0" >total_tax_amount</td>
#       <td id="T_1d8c4_row8_col1" class="data row8 col1" >100.00%</td>
#       <td id="T_1d8c4_row8_col2" class="data row8 col2" >42.00</td>
#       <td id="T_1d8c4_row8_col3" class="data row8 col3" >42.00</td>
#       <td id="T_1d8c4_row8_col4" class="data row8 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1d8c4_row9_col0" class="data row9 col0" >total_amount</td>
#       <td id="T_1d8c4_row9_col1" class="data row9 col1" >100.00%</td>
#       <td id="T_1d8c4_row9_col2" class="data row9 col2" >642.00</td>
#       <td id="T_1d8c4_row9_col3" class="data row9 col3" >642.00</td>
#       <td id="T_1d8c4_row9_col4" class="data row9 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_1d8c4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1d8c4_row10_col0" class="data ro
# <h1 style='border-bottom: 2px solid #334155; padding-bottom: 10px; margin-top: 50px;'>Report: LZD-001</h1>
#     <div style="padding: 20px; border-radius: 10px; background-color: #f8fafc; border-left: 8px solid #4CAF50; margin-bottom: 24px; box-shadow: 0 4px 6px -1px rgb(0 0 0 / 0.1);">
#         <h2 style="margin: 0; color: #1e293b; font-family: sans-serif;">Extraction Accuracy Summary</h2>
#         <div style="display: flex; align-items: center; margin-top: 12px;">
#             <span style="font-size: 16px; color: #64748b; margin-right: 8px;">Overall Score:</span>
#             <span style="color: #16a34a; font-size: 28px; font-weight: bold;">93.49%</span>
#         </div>
#         <p style="margin: 8px 0 0 0; color: #64748b; font-size: 14px;">Total Fields Evaluated: <b style="color: #334155;">13</b></p>
#     </div>
# <style type="text/css">
# #T_7d222 th {
#   background-color: #f8fafc;
#   color: #475569;
#   font-weight: bold;
#   text-transform: uppercase;
#   font-size: 12px;
# }
# #T_7d222 tr:hover {
#   background-color: #f1f5f9;
# }
# #T_7d222_row0_col0, #T_7d222_row0_col2, #T_7d222_row0_col3, #T_7d222_row0_col4, #T_7d222_row1_col0, #T_7d222_row1_col2, #T_7d222_row1_col3, #T_7d222_row1_col4, #T_7d222_row2_col0, #T_7d222_row2_col2, #T_7d222_row2_col3, #T_7d222_row2_col4, #T_7d222_row3_col0, #T_7d222_row3_col2, #T_7d222_row3_col3, #T_7d222_row3_col4, #T_7d222_row4_col0, #T_7d222_row4_col2, #T_7d222_row4_col3, #T_7d222_row4_col4, #T_7d222_row5_col0, #T_7d222_row5_col2, #T_7d222_row5_col3, #T_7d222_row5_col4, #T_7d222_row6_col0, #T_7d222_row6_col2, #T_7d222_row6_col3, #T_7d222_row6_col4, #T_7d222_row7_col0, #T_7d222_row7_col2, #T_7d222_row7_col3, #T_7d222_row7_col4, #T_7d222_row8_col0, #T_7d222_row8_col2, #T_7d222_row8_col3, #T_7d222_row8_col4, #T_7d222_row9_col0, #T_7d222_row9_col2, #T_7d222_row9_col3, #T_7d222_row9_col4, #T_7d222_row10_col0, #T_7d222_row10_col2, #T_7d222_row10_col3, #T_7d222_row10_col4, #T_7d222_row11_col0, #T_7d222_row11_col2, #T_7d222_row11_col3, #T_7d222_row11_col4, #T_7d222_row12_col0, #T_7d222_row12_col2, #T_7d222_row12_col3, #T_7d222_row12_col4 {
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_7d222_row0_col1, #T_7d222_row1_col1, #T_7d222_row2_col1, #T_7d222_row3_col1, #T_7d222_row4_col1, #T_7d222_row5_col1, #T_7d222_row7_col1, #T_7d222_row8_col1, #T_7d222_row10_col1 {
#   background-color: #f0fdf4;
#   color: #166534;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_7d222_row6_col1 {
#   background-color: #fef2f2;
#   color: #991b1b;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_7d222_row9_col1, #T_7d222_row11_col1, #T_7d222_row12_col1 {
#   background-color: #ecfdf5;
#   color: #065f46;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# </style>
# <table id="T_7d222">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d222_level0_col0" class="col_heading level0 col0" >Field</th>
#       <th id="T_7d222_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7d222_level0_col2" class="col_heading level0 col2" >Ground Truth</th>
#       <th id="T_7d222_level0_col3" class="col_heading level0 col3" >Result</th>
#       <th id="T_7d222_level0_col4" class="col_heading level0 col4" >Category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d222_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d222_row0_col0" class="data row0 col0" >invoice_number</td>
#       <td id="T_7d222_row0_col1" class="data row0 col1" >100.00%</td>
#       <td id="T_7d222_row0_col2" class="data row0 col2" >IN0018918431</td>
#       <td id="T_7d222_row0_col3" class="data row0 col3" >IN0018918431</td>
#       <td id="T_7d222_row0_col4" class="data row0 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_7d222_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7d222_row1_col0" class="data row1 col0" >invoice_date</td>
#       <td id="T_7d222_row1_col1" class="data row1 col1" >100.00%</td>
#       <td id="T_7d222_row1_col2" class="data row1 col2" >26/01/2023</td>
#       <td id="T_7d222_row1_col3" class="data row1 col3" >26/01/2023</td>
#       <td id="T_7d222_row1_col4" class="data row1 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_7d222_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7d222_row2_col0" class="data row2 col0" >supplier_name_th</td>
#       <td id="T_7d222_row2_col1" class="data row2 col1" >100.00%</td>
#       <td id="T_7d222_row2_col2" class="data row2 col2" >LAZADA LIMITED</td>
#       <td id="T_7d222_row2_col3" class="data row2 col3" >LAZADA LIMITED</td>
#       <td id="T_7d222_row2_col4" class="data row2 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_7d222_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7d222_row3_col0" class="data row3 col0" >supplier_address_th</td>
#       <td id="T_7d222_row3_col1" class="data row3 col1" >100.00%</td>
#       <td id="T_7d222_row3_col2" class="data row3 col2" >29th Floor Unit 2901 Bhiraj Tower 689, Sukhumvit Road, North Klongton, Vadhana, Bangkok, 10110</td>
#       <td id="T_7d222_row3_col3" class="data row3 col3" >29th Floor Unit 2901 Bhiraj Tower 689, Sukhumvit Road, North Klongton, Vadhana, Bangkok, 10110</td>
#       <td id="T_7d222_row3_col4" class="data row3 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_7d222_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7d222_row4_col0" class="data row4 col0" >supplier_tax_id</td>
#       <td id="T_7d222_row4_col1" class="data row4 col1" >100.00%</td>
#       <td id="T_7d222_row4_col2" class="data row4 col2" >0105555040244</td>
#       <td id="T_7d222_row4_col3" class="data row4 col3" >0105555040244</td>
#       <td id="T_7d222_row4_col4" class="data row4 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_7d222_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7d222_row5_col0" class="data row5 col0" >customer_address_th</td>
#       <td id="T_7d222_row5_col1" class="data row5 col1" >100.00%</td>
#       <td id="T_7d222_row5_col2" class="data row5 col2" >กรุงเทพมหานคร/ Bangkok, 10230</td>
#       <td id="T_7d222_row5_col3" class="data row5 col3" >กรุงเทพมหานคร/ Bangkok, 10230</td>
#       <td id="T_7d222_row5_col4" class="data row5 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_7d222_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7d222_row6_col0" class="data row6 col0" >net_amount</td>
#       <td id="T_7d222_row6_col1" class="data row6 col1" >37.50%</td>
#       <td id="T_7d222_row6_col2" class="data row6 col2" >1,269.00</td>
#       <td id="T_7d222_row6_col3" class="data row6 col3" >1,185.98</td>
#       <td id="T_7d222_row6_col4" class="data row6 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_7d222_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7d222_row7_col0" class="data row7 col0" >total_tax_amount</td>
#       <td id="T_7d222_row7_col1" class="data row7 col1" >100.00%</td>
#       <td id="T_7d222_row7_col2" class="data row7 col2" >83.02</td>
#       <td id="T_7d222_row7_col3" class="data row7 col3" >83.02</td>
#       <td id="T_7d222_row7_col4" class="data row7 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_7d222_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7d222_row8_col0" class="data row8 col0" >total_amount</td>
#       <td id="T_7d222_row8_col1" class="data row8 col1" >100.00%</td>
#       <td id="T_7d222_row8_col2" class="data row8 col2" >1,269.00</td>
#       <td id="T_7d222_row8_col3" class="data row8 col3" >1,269.00</td>
#       <td id="T_7d222_row8_col4" class="data row8 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_7d222_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7d222_row9_col0" class="data row9 col0" >Item_1_description</td>
#       <td id="T_7d222_row9_col1" class="data row9 col1" >91.26%</td>
#       <td id="T_7d222_row9_col2" class="data row9 col2" >Certainty ผ้าอ้อมผู้ใหญ่แบบเทป เซอร์เทนตี้ อีซี่เทป Easy Tapeราคาประหยัด ลัง Super Save ไซส์ L 96 ชิ้น</td>
#       <td id="T_7d222_row9_col3" class="data row9 col3" >Certainly ผ้าอ้อมผู้ใหญ่แบบแท่ง เชอร์เทนส์ อีซี่เทป Easy Taperราคาประหยัด ตั้ง Super Save ไซส์ L 96 ชิ้น</td>
#       <td id="T_7d222_row9_col4" class="data row9 col4" >Line Item</td>
#     </tr>
#     <tr>
#       <th id="T_7d222_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7d222_row10_col0" class="data row10 col0" >Item_1_quantity</td>
#       <td id="T_7d222_row10_col1" class="data row10 col1" >100.00%</td>
#       <td id="T_7d222_row10_col2" class="data row10 col2" >1</td>
#       <td id="T_7d222_row10_col3" class=
# <h1 style='border-bottom: 2px solid #334155; padding-bottom: 10px; margin-top: 50px;'>Report: MSV-001</h1>
#     <div style="padding: 20px; border-radius: 10px; background-color: #f8fafc; border-left: 8px solid #4CAF50; margin-bottom: 24px; box-shadow: 0 4px 6px -1px rgb(0 0 0 / 0.1);">
#         <h2 style="margin: 0; color: #1e293b; font-family: sans-serif;">Extraction Accuracy Summary</h2>
#         <div style="display: flex; align-items: center; margin-top: 12px;">
#             <span style="font-size: 16px; color: #64748b; margin-right: 8px;">Overall Score:</span>
#             <span style="color: #16a34a; font-size: 28px; font-weight: bold;">98.56%</span>
#         </div>
#         <p style="margin: 8px 0 0 0; color: #64748b; font-size: 14px;">Total Fields Evaluated: <b style="color: #334155;">12</b></p>
#     </div>
# <style type="text/css">
# #T_401be th {
#   background-color: #f8fafc;
#   color: #475569;
#   font-weight: bold;
#   text-transform: uppercase;
#   font-size: 12px;
# }
# #T_401be tr:hover {
#   background-color: #f1f5f9;
# }
# #T_401be_row0_col0, #T_401be_row0_col2, #T_401be_row0_col3, #T_401be_row0_col4, #T_401be_row1_col0, #T_401be_row1_col2, #T_401be_row1_col3, #T_401be_row1_col4, #T_401be_row2_col0, #T_401be_row2_col2, #T_401be_row2_col3, #T_401be_row2_col4, #T_401be_row3_col0, #T_401be_row3_col2, #T_401be_row3_col3, #T_401be_row3_col4, #T_401be_row4_col0, #T_401be_row4_col2, #T_401be_row4_col3, #T_401be_row4_col4, #T_401be_row5_col0, #T_401be_row5_col2, #T_401be_row5_col3, #T_401be_row5_col4, #T_401be_row6_col0, #T_401be_row6_col2, #T_401be_row6_col3, #T_401be_row6_col4, #T_401be_row7_col0, #T_401be_row7_col2, #T_401be_row7_col3, #T_401be_row7_col4, #T_401be_row8_col0, #T_401be_row8_col2, #T_401be_row8_col3, #T_401be_row8_col4, #T_401be_row9_col0, #T_401be_row9_col2, #T_401be_row9_col3, #T_401be_row9_col4, #T_401be_row10_col0, #T_401be_row10_col2, #T_401be_row10_col3, #T_401be_row10_col4, #T_401be_row11_col0, #T_401be_row11_col2, #T_401be_row11_col3, #T_401be_row11_col4 {
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_401be_row0_col1, #T_401be_row1_col1, #T_401be_row3_col1, #T_401be_row4_col1, #T_401be_row5_col1, #T_401be_row6_col1, #T_401be_row7_col1, #T_401be_row8_col1, #T_401be_row9_col1, #T_401be_row10_col1, #T_401be_row11_col1 {
#   background-color: #f0fdf4;
#   color: #166534;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_401be_row2_col1 {
#   background-color: #fffbeb;
#   color: #92400e;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# </style>
# <table id="T_401be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_401be_level0_col0" class="col_heading level0 col0" >Field</th>
#       <th id="T_401be_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_401be_level0_col2" class="col_heading level0 col2" >Ground Truth</th>
#       <th id="T_401be_level0_col3" class="col_heading level0 col3" >Result</th>
#       <th id="T_401be_level0_col4" class="col_heading level0 col4" >Category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_401be_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_401be_row0_col0" class="data row0 col0" >invoice_number</td>
#       <td id="T_401be_row0_col1" class="data row0 col1" >100.00%</td>
#       <td id="T_401be_row0_col2" class="data row0 col2" >M68/393</td>
#       <td id="T_401be_row0_col3" class="data row0 col3" >M68/393</td>
#       <td id="T_401be_row0_col4" class="data row0 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_401be_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_401be_row1_col0" class="data row1 col0" >invoice_date</td>
#       <td id="T_401be_row1_col1" class="data row1 col1" >100.00%</td>
#       <td id="T_401be_row1_col2" class="data row1 col2" >17 กันยายน 2568</td>
#       <td id="T_401be_row1_col3" class="data row1 col3" >17 กันยายน 2568</td>
#       <td id="T_401be_row1_col4" class="data row1 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_401be_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_401be_row2_col0" class="data row2 col0" >supplier_name_th</td>
#       <td id="T_401be_row2_col1" class="data row2 col1" >89.23%</td>
#       <td id="T_401be_row2_col2" class="data row2 col2" >บริษัท เอ็ม-เซเว่น (ประเทศไทย) จำกัด</td>
#       <td id="T_401be_row2_col3" class="data row2 col3" >เอ็ม-เซเว่น (ประเทศไทย) จำกัด</td>
#       <td id="T_401be_row2_col4" class="data row2 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_401be_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_401be_row3_col0" class="data row3 col0" >supplier_address_th</td>
#       <td id="T_401be_row3_col1" class="data row3 col1" >100.00%</td>
#       <td id="T_401be_row3_col2" class="data row3 col2" >309, 311 ซอยอ่อนนุช 70/1 ถนนอ่อนนุช แขวงประเวศ เขตประเวศ กรุงเทพฯ 10250</td>
#       <td id="T_401be_row3_col3" class="data row3 col3" >309, 311 ซอยอ่อนนุช 70/1 ถนนอ่อนนุช แขวงประเวศ เขตประเวศ กรุงเทพฯ 10250</td>
#       <td id="T_401be_row3_col4" class="data row3 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_401be_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_401be_row4_col0" class="data row4 col0" >supplier_tax_id</td>
#       <td id="T_401be_row4_col1" class="data row4 col1" >100.00%</td>
#       <td id="T_401be_row4_col2" class="data row4 col2" >0105530029573</td>
#       <td id="T_401be_row4_col3" class="data row4 col3" >0105530029573</td>
#       <td id="T_401be_row4_col4" class="data row4 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_401be_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_401be_row5_col0" class="data row5 col0" >customer_name_th</td>
#       <td id="T_401be_row5_col1" class="data row5 col1" >97.37%</td>
#       <td id="T_401be_row5_col2" class="data row5 col2" >บริษัท อินโนเวทีฟ เอ็กซ์ตรีมิสต์ จำกัด</td>
#       <td id="T_401be_row5_col3" class="data row5 col3" >บริษัท อินโนเวทีฟ เอ็กซ์ตรีมิตส์ จำกัด</td>
#       <td id="T_401be_row5_col4" class="data row5 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_401be_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_401be_row6_col0" class="data row6 col0" >customer_address_th</td>
#       <td id="T_401be_row6_col1" class="data row6 col1" >96.07%</td>
#       <td id="T_401be_row6_col2" class="data row6 col2" >3 อาคารพร้อมพันธุ์ 3 ชั้นที่ 16 ห้องเลขที่ 1608-1614 ซอยลาดพร้าว 3 ถนนลาดพร้าว แขวงจอมพล เขตจตุจักร กรุงเทพฯ 10900</td>
#       <td id="T_401be_row6_col3" class="data row6 col3" >3 อาคารพร้อมพื้นที่ 3 ชั้นที่ 16 ห้องเลขที่ 1608-1614 ซอยลาดพร้าว 3 ถนนลาดพร้าว แขวงจอมพล เขตจตุจักร กรุงเทพฯ 10900</td>
#       <td id="T_401be_row6_col4" class="data row6 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_401be_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_401be_row7_col0" class="data row7 col0" >net_amount</td>
#       <td id="T_401be_row7_col1" class="data row7 col1" >100.00%</td>
#       <td id="T_401be_row7_col2" class="data row7 col2" >11,214.95</td>
#       <td id="T_401be_row7_col3" class="data row7 col3" >11,214.95</td>
#       <td id="T_401be_row7_col4" class="data row7 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_401be_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_401be_row8_col0" class="data row8 col0" >total_tax_amount</td>
#       <td id="T_401be_row8_col1" class="data row8 col1" >100.00%</td>
#       <td id="T_401be_row8_col2" class="data row8 col2" >785.05</td>
#       <td id="T_401be_row8_col3" class="data row8 col3" >785.05</td>
#       <td id="T_401be_row8_col4" class="data row8 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_401be_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_401be_row9_col0" class="data row9 col0" >total_amount</td>
#       <td id="T_401be_row9_col1" class="data row9 col1" >100.00%</td>
#       <td id="T_401be_row9_col2" class="data row9 col2" >12,000.00</td>
#       <td id="T_401be_row9_col3" class="data row9 col3" >12,000.00</td>
#       <td id="T_401be_row9_col4" class="data row9 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_401be_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_401be_row10_col0" class="data row10 col0" >Item_1_description</td>
#       <td id="T_401be_row10_col1" class="data row10 col1" >100.00%</td>
#       <td id="T_401be_row10_col2" class="data row10 col2" >ค่าบริการป้องกันและกำจัดมด แมลงสาบ</td>
#       <td id="T_401be_row10_col3" class="data row10 col3" >ค่าบริการป้องกันและกำจัดมด แมลงสาบ</td>
#       <td id="T_401be_row10_col4" class="data row10 col4" >Line Item</td>
#     </tr>
#     <tr>
#       <th id="T_401be_level0_row11" class="row_heading level0
# <h1 style='border-bottom: 2px solid #334155; padding-bottom: 10px; margin-top: 50px;'>Report: PPP-001</h1>
#     <div style="padding: 20px; border-radius: 10px; background-color: #f8fafc; border-left: 8px solid #4CAF50; margin-bottom: 24px; box-shadow: 0 4px 6px -1px rgb(0 0 0 / 0.1);">
#         <h2 style="margin: 0; color: #1e293b; font-family: sans-serif;">Extraction Accuracy Summary</h2>
#         <div style="display: flex; align-items: center; margin-top: 12px;">
#             <span style="font-size: 16px; color: #64748b; margin-right: 8px;">Overall Score:</span>
#             <span style="color: #16a34a; font-size: 28px; font-weight: bold;">86.83%</span>
#         </div>
#         <p style="margin: 8px 0 0 0; color: #64748b; font-size: 14px;">Total Fields Evaluated: <b style="color: #334155;">35</b></p>
#     </div>
# <style type="text/css">
# #T_6258b th {
#   background-color: #f8fafc;
#   color: #475569;
#   font-weight: bold;
#   text-transform: uppercase;
#   font-size: 12px;
# }
# #T_6258b tr:hover {
#   background-color: #f1f5f9;
# }
# #T_6258b_row0_col0, #T_6258b_row0_col2, #T_6258b_row0_col3, #T_6258b_row0_col4, #T_6258b_row1_col0, #T_6258b_row1_col2, #T_6258b_row1_col3, #T_6258b_row1_col4, #T_6258b_row2_col0, #T_6258b_row2_col2, #T_6258b_row2_col3, #T_6258b_row2_col4, #T_6258b_row3_col0, #T_6258b_row3_col2, #T_6258b_row3_col3, #T_6258b_row3_col4, #T_6258b_row4_col0, #T_6258b_row4_col2, #T_6258b_row4_col3, #T_6258b_row4_col4, #T_6258b_row5_col0, #T_6258b_row5_col2, #T_6258b_row5_col3, #T_6258b_row5_col4, #T_6258b_row6_col0, #T_6258b_row6_col2, #T_6258b_row6_col3, #T_6258b_row6_col4, #T_6258b_row7_col0, #T_6258b_row7_col2, #T_6258b_row7_col3, #T_6258b_row7_col4, #T_6258b_row8_col0, #T_6258b_row8_col2, #T_6258b_row8_col3, #T_6258b_row8_col4, #T_6258b_row9_col0, #T_6258b_row9_col2, #T_6258b_row9_col3, #T_6258b_row9_col4, #T_6258b_row10_col0, #T_6258b_row10_col2, #T_6258b_row10_col3, #T_6258b_row10_col4, #T_6258b_row11_col0, #T_6258b_row11_col2, #T_6258b_row11_col3, #T_6258b_row11_col4, #T_6258b_row12_col0, #T_6258b_row12_col2, #T_6258b_row12_col3, #T_6258b_row12_col4, #T_6258b_row13_col0, #T_6258b_row13_col2, #T_6258b_row13_col3, #T_6258b_row13_col4, #T_6258b_row14_col0, #T_6258b_row14_col2, #T_6258b_row14_col3, #T_6258b_row14_col4, #T_6258b_row15_col0, #T_6258b_row15_col2, #T_6258b_row15_col3, #T_6258b_row15_col4, #T_6258b_row16_col0, #T_6258b_row16_col2, #T_6258b_row16_col3, #T_6258b_row16_col4, #T_6258b_row17_col0, #T_6258b_row17_col2, #T_6258b_row17_col3, #T_6258b_row17_col4, #T_6258b_row18_col0, #T_6258b_row18_col2, #T_6258b_row18_col3, #T_6258b_row18_col4, #T_6258b_row19_col0, #T_6258b_row19_col2, #T_6258b_row19_col3, #T_6258b_row19_col4, #T_6258b_row20_col0, #T_6258b_row20_col2, #T_6258b_row20_col3, #T_6258b_row20_col4, #T_6258b_row21_col0, #T_6258b_row21_col2, #T_6258b_row21_col3, #T_6258b_row21_col4, #T_6258b_row22_col0, #T_6258b_row22_col2, #T_6258b_row22_col3, #T_6258b_row22_col4, #T_6258b_row23_col0, #T_6258b_row23_col2, #T_6258b_row23_col3, #T_6258b_row23_col4, #T_6258b_row24_col0, #T_6258b_row24_col2, #T_6258b_row24_col3, #T_6258b_row24_col4, #T_6258b_row25_col0, #T_6258b_row25_col2, #T_6258b_row25_col3, #T_6258b_row25_col4, #T_6258b_row26_col0, #T_6258b_row26_col2, #T_6258b_row26_col3, #T_6258b_row26_col4, #T_6258b_row27_col0, #T_6258b_row27_col2, #T_6258b_row27_col3, #T_6258b_row27_col4, #T_6258b_row28_col0, #T_6258b_row28_col2, #T_6258b_row28_col3, #T_6258b_row28_col4, #T_6258b_row29_col0, #T_6258b_row29_col2, #T_6258b_row29_col3, #T_6258b_row29_col4, #T_6258b_row30_col0, #T_6258b_row30_col2, #T_6258b_row30_col3, #T_6258b_row30_col4, #T_6258b_row31_col0, #T_6258b_row31_col2, #T_6258b_row31_col3, #T_6258b_row31_col4, #T_6258b_row32_col0, #T_6258b_row32_col2, #T_6258b_row32_col3, #T_6258b_row32_col4, #T_6258b_row33_col0, #T_6258b_row33_col2, #T_6258b_row33_col3, #T_6258b_row33_col4, #T_6258b_row34_col0, #T_6258b_row34_col2, #T_6258b_row34_col3, #T_6258b_row34_col4 {
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_6258b_row0_col1, #T_6258b_row3_col1, #T_6258b_row4_col1, #T_6258b_row7_col1, #T_6258b_row8_col1, #T_6258b_row13_col1, #T_6258b_row14_col1, #T_6258b_row17_col1, #T_6258b_row18_col1, #T_6258b_row20_col1, #T_6258b_row21_col1, #T_6258b_row22_col1, #T_6258b_row24_col1, #T_6258b_row25_col1, #T_6258b_row26_col1, #T_6258b_row28_col1, #T_6258b_row29_col1, #T_6258b_row30_col1, #T_6258b_row32_col1, #T_6258b_row33_col1, #T_6258b_row34_col1 {
#   background-color: #f0fdf4;
#   color: #166534;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_6258b_row1_col1, #T_6258b_row9_col1, #T_6258b_row10_col1 {
#   background-color: #fef2f2;
#   color: #991b1b;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_6258b_row2_col1, #T_6258b_row6_col1, #T_6258b_row12_col1, #T_6258b_row16_col1 {
#   background-color: #ecfdf5;
#   color: #065f46;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_6258b_row5_col1, #T_6258b_row11_col1, #T_6258b_row15_col1, #T_6258b_row19_col1, #T_6258b_row23_col1, #T_6258b_row27_col1, #T_6258b_row31_col1 {
#   background-color: #fffbeb;
#   color: #92400e;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# </style>
# <table id="T_6258b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6258b_level0_col0" class="col_heading level0 col0" >Field</th>
#       <th id="T_6258b_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_6258b_level0_col2" class="col_heading level0 col2" >Ground Truth</th>
#       <th id="T_6258b_level0_col3" class="col_heading level0 col3" >Result</th>
#       <th id="T_6258b_level0_col4" class="col_heading level0 col4" >Category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6258b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6258b_row0_col0" class="data row0 col0" >invoice_number</td>
#       <td id="T_6258b_row0_col1" class="data row0 col1" >100.00%</td>
#       <td id="T_6258b_row0_col2" class="data row0 col2" >R36810186</td>
#       <td id="T_6258b_row0_col3" class="data row0 col3" >R36810186</td>
#       <td id="T_6258b_row0_col4" class="data row0 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_6258b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6258b_row1_col0" class="data row1 col0" >invoice_date</td>
#       <td id="T_6258b_row1_col1" class="data row1 col1" >0.00%</td>
#       <td id="T_6258b_row1_col2" class="data row1 col2" >07/10/68</td>
#       <td id="T_6258b_row1_col3" class="data row1 col3" ></td>
#       <td id="T_6258b_row1_col4" class="data row1 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_6258b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6258b_row2_col0" class="data row2 col0" >supplier_name_th</td>
#       <td id="T_6258b_row2_col1" class="data row2 col1" >94.29%</td>
#       <td id="T_6258b_row2_col2" class="data row2 col2" >บริษัท เพิ่มพูล ประสิทธิ์-ตุ๊ จำกัด</td>
#       <td id="T_6258b_row2_col3" class="data row2 col3" >บริษัท เพิ่มพูล ประสิทธิ์-ตู้ จำกัด</td>
#       <td id="T_6258b_row2_col4" class="data row2 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_6258b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6258b_row3_col0" class="data row3 col0" >supplier_address_th</td>
#       <td id="T_6258b_row3_col1" class="data row3 col1" >100.00%</td>
#       <td id="T_6258b_row3_col2" class="data row3 col2" >637 ถ.ลาดพร้าว แขวงจอมพล เขตจตุจักร กรุงเทพฯ. 10900</td>
#       <td id="T_6258b_row3_col3" class="data row3 col3" >637 ถ.ลาดพร้าว แขวงจอมพล เขตจตุจักร กรุงเทพฯ. 10900</td>
#       <td id="T_6258b_row3_col4" class="data row3 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_6258b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6258b_row4_col0" class="data row4 col0" >supplier_tax_id</td>
#       <td id="T_6258b_row4_col1" class="data row4 col1" >100.00%</td>
#       <td id="T_6258b_row4_col2" class="data row4 col2" >0105534071621</td>
#       <td id="T_6258b_row4_col3" class="data row4 col3" >0105534071621</td>
#       <td id="T_6258b_row4_col4" class="data row4 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_6258b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6258b_row5_col0" class="data row5 col0" >customer_name_th</td>
#       <td id="T_6258b_row5_col1" class="data row5 col1" >81.36%</td>
#       <td id="T_6258b_row5_col2" class="data row5 col2" >บจก. อินโนเวทีฟ เอ็กซ์ตรีมิสต์</td>
#       <td id="T_6258b_row5_col3" class="data row5 col3" >บอค. อินโนเวสท์ เอกซ์ตรีมิตส์</td>
# <h1 style='border-bottom: 2px solid #334155; padding-bottom: 10px; margin-top: 50px;'>Report: PPP-002</h1>
#     <div style="padding: 20px; border-radius: 10px; background-color: #f8fafc; border-left: 8px solid #4CAF50; margin-bottom: 24px; box-shadow: 0 4px 6px -1px rgb(0 0 0 / 0.1);">
#         <h2 style="margin: 0; color: #1e293b; font-family: sans-serif;">Extraction Accuracy Summary</h2>
#         <div style="display: flex; align-items: center; margin-top: 12px;">
#             <span style="font-size: 16px; color: #64748b; margin-right: 8px;">Overall Score:</span>
#             <span style="color: #16a34a; font-size: 28px; font-weight: bold;">84.03%</span>
#         </div>
#         <p style="margin: 8px 0 0 0; color: #64748b; font-size: 14px;">Total Fields Evaluated: <b style="color: #334155;">23</b></p>
#     </div>
# <style type="text/css">
# #T_be9f3 th {
#   background-color: #f8fafc;
#   color: #475569;
#   font-weight: bold;
#   text-transform: uppercase;
#   font-size: 12px;
# }
# #T_be9f3 tr:hover {
#   background-color: #f1f5f9;
# }
# #T_be9f3_row0_col0, #T_be9f3_row0_col2, #T_be9f3_row0_col3, #T_be9f3_row0_col4, #T_be9f3_row1_col0, #T_be9f3_row1_col2, #T_be9f3_row1_col3, #T_be9f3_row1_col4, #T_be9f3_row2_col0, #T_be9f3_row2_col2, #T_be9f3_row2_col3, #T_be9f3_row2_col4, #T_be9f3_row3_col0, #T_be9f3_row3_col2, #T_be9f3_row3_col3, #T_be9f3_row3_col4, #T_be9f3_row4_col0, #T_be9f3_row4_col2, #T_be9f3_row4_col3, #T_be9f3_row4_col4, #T_be9f3_row5_col0, #T_be9f3_row5_col2, #T_be9f3_row5_col3, #T_be9f3_row5_col4, #T_be9f3_row6_col0, #T_be9f3_row6_col2, #T_be9f3_row6_col3, #T_be9f3_row6_col4, #T_be9f3_row7_col0, #T_be9f3_row7_col2, #T_be9f3_row7_col3, #T_be9f3_row7_col4, #T_be9f3_row8_col0, #T_be9f3_row8_col2, #T_be9f3_row8_col3, #T_be9f3_row8_col4, #T_be9f3_row9_col0, #T_be9f3_row9_col2, #T_be9f3_row9_col3, #T_be9f3_row9_col4, #T_be9f3_row10_col0, #T_be9f3_row10_col2, #T_be9f3_row10_col3, #T_be9f3_row10_col4, #T_be9f3_row11_col0, #T_be9f3_row11_col2, #T_be9f3_row11_col3, #T_be9f3_row11_col4, #T_be9f3_row12_col0, #T_be9f3_row12_col2, #T_be9f3_row12_col3, #T_be9f3_row12_col4, #T_be9f3_row13_col0, #T_be9f3_row13_col2, #T_be9f3_row13_col3, #T_be9f3_row13_col4, #T_be9f3_row14_col0, #T_be9f3_row14_col2, #T_be9f3_row14_col3, #T_be9f3_row14_col4, #T_be9f3_row15_col0, #T_be9f3_row15_col2, #T_be9f3_row15_col3, #T_be9f3_row15_col4, #T_be9f3_row16_col0, #T_be9f3_row16_col2, #T_be9f3_row16_col3, #T_be9f3_row16_col4, #T_be9f3_row17_col0, #T_be9f3_row17_col2, #T_be9f3_row17_col3, #T_be9f3_row17_col4, #T_be9f3_row18_col0, #T_be9f3_row18_col2, #T_be9f3_row18_col3, #T_be9f3_row18_col4, #T_be9f3_row19_col0, #T_be9f3_row19_col2, #T_be9f3_row19_col3, #T_be9f3_row19_col4, #T_be9f3_row20_col0, #T_be9f3_row20_col2, #T_be9f3_row20_col3, #T_be9f3_row20_col4, #T_be9f3_row21_col0, #T_be9f3_row21_col2, #T_be9f3_row21_col3, #T_be9f3_row21_col4, #T_be9f3_row22_col0, #T_be9f3_row22_col2, #T_be9f3_row22_col3, #T_be9f3_row22_col4 {
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_be9f3_row0_col1, #T_be9f3_row1_col1, #T_be9f3_row3_col1, #T_be9f3_row4_col1, #T_be9f3_row7_col1, #T_be9f3_row8_col1, #T_be9f3_row9_col1, #T_be9f3_row10_col1, #T_be9f3_row11_col1, #T_be9f3_row15_col1 {
#   background-color: #f0fdf4;
#   color: #166534;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_be9f3_row2_col1, #T_be9f3_row19_col1 {
#   background-color: #fffbeb;
#   color: #92400e;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_be9f3_row5_col1, #T_be9f3_row12_col1, #T_be9f3_row16_col1, #T_be9f3_row20_col1 {
#   background-color: #fef2f2;
#   color: #991b1b;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_be9f3_row6_col1, #T_be9f3_row13_col1, #T_be9f3_row14_col1, #T_be9f3_row17_col1, #T_be9f3_row18_col1, #T_be9f3_row21_col1, #T_be9f3_row22_col1 {
#   background-color: #ecfdf5;
#   color: #065f46;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# </style>
# <table id="T_be9f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be9f3_level0_col0" class="col_heading level0 col0" >Field</th>
#       <th id="T_be9f3_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_be9f3_level0_col2" class="col_heading level0 col2" >Ground Truth</th>
#       <th id="T_be9f3_level0_col3" class="col_heading level0 col3" >Result</th>
#       <th id="T_be9f3_level0_col4" class="col_heading level0 col4" >Category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be9f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be9f3_row0_col0" class="data row0 col0" >invoice_number</td>
#       <td id="T_be9f3_row0_col1" class="data row0 col1" >100.00%</td>
#       <td id="T_be9f3_row0_col2" class="data row0 col2" >R36810185</td>
#       <td id="T_be9f3_row0_col3" class="data row0 col3" >R36810185</td>
#       <td id="T_be9f3_row0_col4" class="data row0 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_be9f3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_be9f3_row1_col0" class="data row1 col0" >invoice_date</td>
#       <td id="T_be9f3_row1_col1" class="data row1 col1" >100.00%</td>
#       <td id="T_be9f3_row1_col2" class="data row1 col2" >07/10/68</td>
#       <td id="T_be9f3_row1_col3" class="data row1 col3" >07/10/68</td>
#       <td id="T_be9f3_row1_col4" class="data row1 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_be9f3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_be9f3_row2_col0" class="data row2 col0" >supplier_name_th</td>
#       <td id="T_be9f3_row2_col1" class="data row2 col1" >88.57%</td>
#       <td id="T_be9f3_row2_col2" class="data row2 col2" >บริษัท เพิ่มพูล ประสิทธิ์-ตุ๊ จำกัด</td>
#       <td id="T_be9f3_row2_col3" class="data row2 col3" >บริษัท เพิ่มพูด ประสิทธิ์-คู่ จำกัด</td>
#       <td id="T_be9f3_row2_col4" class="data row2 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_be9f3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_be9f3_row3_col0" class="data row3 col0" >supplier_address_th</td>
#       <td id="T_be9f3_row3_col1" class="data row3 col1" >99.03%</td>
#       <td id="T_be9f3_row3_col2" class="data row3 col2" >637 ถ.ลาดพร้าว แขวงจอมพล เขตจตุจักร กรุงเทพฯ. 10900</td>
#       <td id="T_be9f3_row3_col3" class="data row3 col3" >637 ถ.ลาดพร้าว แขวงจอมพล เขตจตุจักร กรุงเทพฯ. 10900.</td>
#       <td id="T_be9f3_row3_col4" class="data row3 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_be9f3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_be9f3_row4_col0" class="data row4 col0" >supplier_tax_id</td>
#       <td id="T_be9f3_row4_col1" class="data row4 col1" >100.00%</td>
#       <td id="T_be9f3_row4_col2" class="data row4 col2" >0105534071621</td>
#       <td id="T_be9f3_row4_col3" class="data row4 col3" >0105534071621</td>
#       <td id="T_be9f3_row4_col4" class="data row4 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_be9f3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_be9f3_row5_col0" class="data row5 col0" >customer_name_th</td>
#       <td id="T_be9f3_row5_col1" class="data row5 col1" >48.28%</td>
#       <td id="T_be9f3_row5_col2" class="data row5 col2" >บจก. อินโนเวทีฟ เอ็กซ์ตรีมิสต์</td>
#       <td id="T_be9f3_row5_col3" class="data row5 col3" >บชก.อินโฟเวย์ส แอลซีฟิวเจอร์</td>
#       <td id="T_be9f3_row5_col4" class="data row5 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_be9f3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_be9f3_row6_col0" class="data row6 col0" >customer_address_th</td>
#       <td id="T_be9f3_row6_col1" class="data row6 col1" >92.73%</td>
#       <td id="T_be9f3_row6_col2" class="data row6 col2" >3 อาคารพร้อมพันธุ์ 3 ชั้น 16 ห้อง 1608-1614
# ซอยลาดพร้าว 3 ถนนลาดพร้าว เเขวงจอมพล เขตจตุจักร กรุงเทพมหานคร 10900</td>
#       <td id="T_be9f3_row6_col3" class="data row6 col3" >อาคารพร้อมพื้นที่ 3 ชั้น 16 ห้อง 1608-1614 ซอยลาดพร้าว 3 ถนนลาดพร้าว แขวงจอมพล เขตจตุจักร กรุงเทพมหานคร 10900</td>
#       <td id="T_be9f3_row6_col4" class="data row6 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_be9f3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_be9f3_row7_col0" class="data row7 col0" >customer_tax_id</td>
#       <td id="T_be9f3_row7_col1" class="data row7 col1" >96.00%</td>
#       <td id="T_be9f3_row7_col2" class="data row7 col2" >0105551117714</td>
#       <td id="T_be9f3_row7_col3" class="data row7 col3" >010551117714</td>
#       <td id="T_be9f3_row7_col4" class="data row7 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_be9f3_level0_row8" class=
# <h1 style='border-bottom: 2px solid #334155; padding-bottom: 10px; margin-top: 50px;'>Report: PTV-001</h1>
#     <div style="padding: 20px; border-radius: 10px; background-color: #f8fafc; border-left: 8px solid #4CAF50; margin-bottom: 24px; box-shadow: 0 4px 6px -1px rgb(0 0 0 / 0.1);">
#         <h2 style="margin: 0; color: #1e293b; font-family: sans-serif;">Extraction Accuracy Summary</h2>
#         <div style="display: flex; align-items: center; margin-top: 12px;">
#             <span style="font-size: 16px; color: #64748b; margin-right: 8px;">Overall Score:</span>
#             <span style="color: #16a34a; font-size: 28px; font-weight: bold;">93.26%</span>
#         </div>
#         <p style="margin: 8px 0 0 0; color: #64748b; font-size: 14px;">Total Fields Evaluated: <b style="color: #334155;">12</b></p>
#     </div>
# <style type="text/css">
# #T_c8a6c th {
#   background-color: #f8fafc;
#   color: #475569;
#   font-weight: bold;
#   text-transform: uppercase;
#   font-size: 12px;
# }
# #T_c8a6c tr:hover {
#   background-color: #f1f5f9;
# }
# #T_c8a6c_row0_col0, #T_c8a6c_row0_col2, #T_c8a6c_row0_col3, #T_c8a6c_row0_col4, #T_c8a6c_row1_col0, #T_c8a6c_row1_col2, #T_c8a6c_row1_col3, #T_c8a6c_row1_col4, #T_c8a6c_row2_col0, #T_c8a6c_row2_col2, #T_c8a6c_row2_col3, #T_c8a6c_row2_col4, #T_c8a6c_row3_col0, #T_c8a6c_row3_col2, #T_c8a6c_row3_col3, #T_c8a6c_row3_col4, #T_c8a6c_row4_col0, #T_c8a6c_row4_col2, #T_c8a6c_row4_col3, #T_c8a6c_row4_col4, #T_c8a6c_row5_col0, #T_c8a6c_row5_col2, #T_c8a6c_row5_col3, #T_c8a6c_row5_col4, #T_c8a6c_row6_col0, #T_c8a6c_row6_col2, #T_c8a6c_row6_col3, #T_c8a6c_row6_col4, #T_c8a6c_row7_col0, #T_c8a6c_row7_col2, #T_c8a6c_row7_col3, #T_c8a6c_row7_col4, #T_c8a6c_row8_col0, #T_c8a6c_row8_col2, #T_c8a6c_row8_col3, #T_c8a6c_row8_col4, #T_c8a6c_row9_col0, #T_c8a6c_row9_col2, #T_c8a6c_row9_col3, #T_c8a6c_row9_col4, #T_c8a6c_row10_col0, #T_c8a6c_row10_col2, #T_c8a6c_row10_col3, #T_c8a6c_row10_col4, #T_c8a6c_row11_col0, #T_c8a6c_row11_col2, #T_c8a6c_row11_col3, #T_c8a6c_row11_col4 {
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_c8a6c_row0_col1, #T_c8a6c_row1_col1, #T_c8a6c_row3_col1, #T_c8a6c_row4_col1, #T_c8a6c_row5_col1, #T_c8a6c_row7_col1, #T_c8a6c_row8_col1, #T_c8a6c_row9_col1, #T_c8a6c_row11_col1 {
#   background-color: #f0fdf4;
#   color: #166534;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_c8a6c_row2_col1 {
#   background-color: #fef2f2;
#   color: #991b1b;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# #T_c8a6c_row6_col1, #T_c8a6c_row10_col1 {
#   background-color: #fffbeb;
#   color: #92400e;
#   font-weight: bold;
#   text-align: left;
#   padding: 12px 15px;
#   border-bottom: 1px solid #e2e8f0;
#   font-family: sans-serif;
# }
# </style>
# <table id="T_c8a6c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8a6c_level0_col0" class="col_heading level0 col0" >Field</th>
#       <th id="T_c8a6c_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_c8a6c_level0_col2" class="col_heading level0 col2" >Ground Truth</th>
#       <th id="T_c8a6c_level0_col3" class="col_heading level0 col3" >Result</th>
#       <th id="T_c8a6c_level0_col4" class="col_heading level0 col4" >Category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8a6c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8a6c_row0_col0" class="data row0 col0" >invoice_number</td>
#       <td id="T_c8a6c_row0_col1" class="data row0 col1" >100.00%</td>
#       <td id="T_c8a6c_row0_col2" class="data row0 col2" >68101365</td>
#       <td id="T_c8a6c_row0_col3" class="data row0 col3" >68101365</td>
#       <td id="T_c8a6c_row0_col4" class="data row0 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_c8a6c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c8a6c_row1_col0" class="data row1 col0" >invoice_date</td>
#       <td id="T_c8a6c_row1_col1" class="data row1 col1" >100.00%</td>
#       <td id="T_c8a6c_row1_col2" class="data row1 col2" >24/10/2025</td>
#       <td id="T_c8a6c_row1_col3" class="data row1 col3" >24/10/2025</td>
#       <td id="T_c8a6c_row1_col4" class="data row1 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_c8a6c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c8a6c_row2_col0" class="data row2 col0" >supplier_name_th</td>
#       <td id="T_c8a6c_row2_col1" class="data row2 col1" >66.67%</td>
#       <td id="T_c8a6c_row2_col2" class="data row2 col2" >บริษัท พันธวณิช จำกัด</td>
#       <td id="T_c8a6c_row2_col3" class="data row2 col3" >พันธวินัย จำกัด</td>
#       <td id="T_c8a6c_row2_col4" class="data row2 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_c8a6c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c8a6c_row3_col0" class="data row3 col0" >supplier_address_th</td>
#       <td id="T_c8a6c_row3_col1" class="data row3 col1" >98.34%</td>
#       <td id="T_c8a6c_row3_col2" class="data row3 col2" >1168/94 อาคารลุมพินีทาวเวอร์ ชั้น 31 ถนนพระราม 4 แขวงทุ่งมหาเมฆ เขตสาทร กรุงเทพมหานคร 10120</td>
#       <td id="T_c8a6c_row3_col3" class="data row3 col3" >1168/94 อาคารอุมพินทาวเวอร์ ชั้น 31 ถนนพระราม 4 แขวงทุ่งมหาเมฆ เขตสาทร กรุงเทพมหานคร 10120</td>
#       <td id="T_c8a6c_row3_col4" class="data row3 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_c8a6c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c8a6c_row4_col0" class="data row4 col0" >supplier_tax_id</td>
#       <td id="T_c8a6c_row4_col1" class="data row4 col1" >100.00%</td>
#       <td id="T_c8a6c_row4_col2" class="data row4 col2" >0105544028248</td>
#       <td id="T_c8a6c_row4_col3" class="data row4 col3" >0105544028248</td>
#       <td id="T_c8a6c_row4_col4" class="data row4 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_c8a6c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c8a6c_row5_col0" class="data row5 col0" >customer_name_th</td>
#       <td id="T_c8a6c_row5_col1" class="data row5 col1" >100.00%</td>
#       <td id="T_c8a6c_row5_col2" class="data row5 col2" >บจ. อินโนเวทีฟ เอ็กซ์ตรีมิสต์</td>
#       <td id="T_c8a6c_row5_col3" class="data row5 col3" >บจ. อินโนเวทีฟ เอ็กซ์ตรีมิสต์</td>
#       <td id="T_c8a6c_row5_col4" class="data row5 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_c8a6c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c8a6c_row6_col0" class="data row6 col0" >customer_address_th</td>
#       <td id="T_c8a6c_row6_col1" class="data row6 col1" >73.93%</td>
#       <td id="T_c8a6c_row6_col2" class="data row6 col2" >3 อาคารพร้อมพันธุ์ 3 ชั้น 16 ห้อง 1608-1614 ซอยลาดพร้าว 3 ถน
# นลาดพร้าว แขวงจอมพล เขตจตุจักร กรุงเทพฯ 10900</td>
#       <td id="T_c8a6c_row6_col3" class="data row6 col3" >บจ. อินโนเวทีฟ เอ็กซ์ตรีมิสต์
# 3 อาคารพร้อมพื้นที่ ชั้น 16 ห้องเลขที่ 608-1614 ชั้น 16 ซอยลาดพร้าว3
# ถนนลาดพร้าว แขวงจอมพล เขตจตุจักร กรุงเทพมหานคร 10900</td>
#       <td id="T_c8a6c_row6_col4" class="data row6 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_c8a6c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c8a6c_row7_col0" class="data row7 col0" >net_amount</td>
#       <td id="T_c8a6c_row7_col1" class="data row7 col1" >100.00%</td>
#       <td id="T_c8a6c_row7_col2" class="data row7 col2" >1,740.00</td>
#       <td id="T_c8a6c_row7_col3" class="data row7 col3" >1,740.00</td>
#       <td id="T_c8a6c_row7_col4" class="data row7 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_c8a6c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c8a6c_row8_col0" class="data row8 col0" >total_tax_amount</td>
#       <td id="T_c8a6c_row8_col1" class="data row8 col1" >100.00%</td>
#       <td id="T_c8a6c_row8_col2" class="data row8 col2" >121.80</td>
#       <td id="T_c8a6c_row8_col3" class="data row8 col3" >121.80</td>
#       <td id="T_c8a6c_row8_col4" class="data row8 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_c8a6c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c8a6c_row9_col0" class="data row9 col0" >total_amount</td>
#       <td id="T_c8a6c_row9_col1" class="data row9 col1" >100.00%</td>
#       <td id="T_c8a6c_row9_col2" class="data row9 col2" >1,861.80</td>
#       <td id="T_c8a6c_row9_col3" class="data row9 col3" >1,861.80</td>
#       <td id="T_c8a6c_row9_col4" class="data row9 col4" >Header</td>
#     </tr>
#     <tr>
#       <th id="T_c8a6c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c8a6c_row10_col0" class="data row10 col0" >Item_1_description</td>
#       <td id="T_c8a6c_row10_col1" class="data row10 col1" >80.23%</td>
#       <td id="T_c8a6c_row10_col2" class="data row10 col2" >รับชำระค่าบริการสำหรับรายได้ค่าบริการซื้อขายออนไลน์ (Online Purchasing) ตามใบแจ้งหนี้เลขที่ : INOP25018281</td

# %% [markdown]
# ---

# %% [markdown]
# ## Overview visualisation

# %%
# FINAL BATCH SUMMARY
display(HTML("<h1 style='color: white; margin-top: 40px;'>Batch Processing Final Results</h1>"))

summary_df = pd.DataFrame(batch_summary)

if not summary_df.empty:
    # Aggregate Score
    avg_batch_score = summary_df['Score'].mean()
    
    display(HTML(f"""
    <div style='background: linear-gradient(135deg, #1e293b 0%, #334155 100%); color: white; padding: 30px; border-radius: 15px; margin-bottom: 30px;'>
        <h2 style='margin: 0; opacity: 0.8;'>Aggregate Accuracy</h2>
        <div style='font-size: 48px; font-weight: bold;'>{avg_batch_score:.2f}%</div>
        <div style='margin-top: 10px; font-size: 16px;'>Across {len(summary_df)} documents</div>
    </div>
    """))

    # Plotting Leaderboard
    plt.figure(figsize=(12, 6))
    plt.bar(summary_df['File'], summary_df['Score'], color='#6366f1')
    plt.axhline(y=avg_batch_score, color='#ef4444', linestyle='--', label=f'Average ({avg_batch_score:.1f}%)')
    plt.title("Comparison Score per Document", fontsize=15, fontweight='bold')
    plt.ylabel("Accuracy %")
    plt.ylim(0, 110)
    plt.legend()
    plt.grid(axis='y', alpha=0.2)
    plt.show()

    # Detailed Final Styler
    def final_score_style(val):
        color = '#16a34a' if val > 90 else '#eab308' if val > 75 else '#ef4444'
        return f'color: {color}; font-weight: bold;'

    # Display final results table
    display(HTML("<h3>Document Leaderboard</h3>"))
    display(summary_df.style.map(final_score_style, subset=['Score'])\
                      .format({"Score": "{:.2f}%"})\
                      .set_properties(**{'text-align': 'center', 'padding': '15px'})\
                      .hide(axis='index'))
else:
    print("No results to summarize.")
# Out:
# <h1 style='color: white; margin-top: 40px;'>Batch Processing Final Results</h1>
#     <div style='background: linear-gradient(135deg, #1e293b 0%, #334155 100%); color: white; padding: 30px; border-radius: 15px; margin-bottom: 30px;'>
#         <h2 style='margin: 0; opacity: 0.8;'>Aggregate Accuracy</h2>
#         <div style='font-size: 48px; font-weight: bold;'>90.82%</div>
#         <div style='margin-top: 10px; font-size: 16px;'>Across 6 documents</div>
#     </div>
# <h3>Document Leaderboard</h3>
# <style type="text/css">
# #T_15760_row0_col0, #T_15760_row0_col2, #T_15760_row1_col0, #T_15760_row1_col2, #T_15760_row2_col0, #T_15760_row2_col2, #T_15760_row3_col0, #T_15760_row3_col2, #T_15760_row4_col0, #T_15760_row4_col2, #T_15760_row5_col0, #T_15760_row5_col2 {
#   text-align: center;
#   padding: 15px;
# }
# #T_15760_row0_col1, #T_15760_row3_col1, #T_15760_row4_col1 {
#   color: #eab308;
#   font-weight: bold;
#   text-align: center;
#   padding: 15px;
# }
# #T_15760_row1_col1, #T_15760_row2_col1, #T_15760_row5_col1 {
#   color: #16a34a;
#   font-weight: bold;
#   text-align: center;
#   padding: 15px;
# }
# </style>
# <table id="T_15760">
#   <thead>
#     <tr>
#       <th id="T_15760_level0_col0" class="col_heading level0 col0" >File</th>
#       <th id="T_15760_level0_col1" class="col_heading level0 col1" >Score</th>
#       <th id="T_15760_level0_col2" class="col_heading level0 col2" >Fields</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_15760_row0_col0" class="data row0 col0" >INT-001</td>
#       <td id="T_15760_row0_col1" class="data row0 col1" >88.74%</td>
#       <td id="T_15760_row0_col2" class="data row0 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_15760_row1_col0" class="data row1 col0" >LZD-001</td>
#       <td id="T_15760_row1_col1" class="data row1 col1" >93.49%</td>
#       <td id="T_15760_row1_col2" class="data row1 col2" >13</td>
#     </tr>
#     <tr>
#       <td id="T_15760_row2_col0" class="data row2 col0" >MSV-001</td>
#       <td id="T_15760_row2_col1" class="data row2 col1" >98.56%</td>
#       <td id="T_15760_row2_col2" class="data row2 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_15760_row3_col0" class="data row3 col0" >PPP-001</td>
#       <td id="T_15760_row3_col1" class="data row3 col1" >86.83%</td>
#       <td id="T_15760_row3_col2" class="data row3 col2" >35</td>
#     </tr>
#     <tr>
#       <td id="T_15760_row4_col0" class="data row4 col0" >PPP-002</td>
#       <td id="T_15760_row4_col1" class="data row4 col1" >84.03%</td>
#       <td id="T_15760_row4_col2" class="data row4 col2" >23</td>
#     </tr>
#     <tr>
#       <td id="T_15760_row5_col0" class="data row5 col0" >PTV-001</td>
#       <td id="T_15760_row5_col1" class="data row5 col1" >93.26%</td>
#       <td id="T_15760_row5_col2" class="data row5 col2" >12</td>
#     </tr>
#   </tbody>
# </table>
