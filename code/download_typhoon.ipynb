# %%
# !curl -LsSf https://hf.co/cli/install.sh | bash
# Out:
# [INFO] Installing Hugging Face CLI...
# [INFO] OS: macos
# [INFO] Force reinstall: false
# [INFO] Install dir: /Users/pat/.hf-cli
# [INFO] Bin dir: /Users/pat/.local/bin
# [INFO] Requested version: latest
# [INFO] Skip PATH update: false
# [INFO] Using Python: Python 3.11.0
# [INFO] Creating directories...
# [INFO] Creating virtual environment...
# [INFO] Virtual environment already exists; reusing (pass --force to recreate)
# [INFO] Installing The Hugging Face CLI (latest)...
# [INFO] Installation output suppressed; set HF_CLI_VERBOSE_PIP=1 for full logs
# [INFO] Linking hf CLI into /Users/pat/.local/bin...
# [INFO] hf available at /Users/pat/.local/bin/hf (symlink to venv)
# [INFO] Run without touching PATH: env PATH="/Users/pat/.local/bin:$PATH" hf --help
# [INFO] /Users/pat/.local/bin is not in your PATH
# [INFO] Verifying installation...
# [SUCCESS] Hugging Face CLI installed successfully!
# [INFO] CLI location: /Users/pat/.local/bin/hf
# ...

# %%
# !python3 -m pip install --upgrade huggingface_hub
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv

load_dotenv()

# Add ~/.local/bin to PATH so hf command works
os.environ["PATH"] += os.pathsep + "/Users/pat/.local/bin"

# Define variables
HF_TOKEN = os.getenv("HF_TOKEN")
MODEL_NAME = os.getenv("MODEL_NAME")
MODEL_DIR = os.getenv("MODEL_DIR")

# %%
# !hf auth login --token {HF_TOKEN}
# !hf download {MODEL_NAME} --local-dir {MODEL_DIR} --cache-dir {MODEL_DIR}
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `hf`CLI if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# The token `ex1` has been saved to /Users/pat/.cache/huggingface/stored_tokens
# Your token has been saved to /Users/pat/.cache/huggingface/token
# Login successful.
# The current active token is: `ex1`
# ...
# Fetching 17 files:  41%|██████████▎              | 7/17 [00:11<00:16,  1.69s/it]
# Cancellation requested; stopping current tasks.
# ...

# %%
# !export TGIS_IMAGE="quay.io/modh/text-generation-inference:rhoai-2.8-58cac74"
# !podman pull ${TGIS_IMAGE}
# Out:
# zsh:1: command not found: podman
